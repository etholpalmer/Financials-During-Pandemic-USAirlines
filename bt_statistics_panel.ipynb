# %%
# Created Library 

import panel as pn
pn.extension('plotly')

import plotly.express as px

import plotly

import pandas as pd

import hvplot.pandas

from matplotlib import pyplot as plt

import os

from pathlib import Path

import numpy as np

from bokeh.plotting import figure, show

from bokeh.io import output_notebook

from holoviews import opts

from bokeh.models.formatters import DatetimeTickFormatter

from bokeh.models.formatters import BasicTickFormatter

import holoviews as hv

from holoviews import opts

# %%
# Imported cleaned csv files in preparation for visualization

# All U.S. Carriers Data

us_passengers_final = pd.read_csv("Data/us_passengers_final.csv")
us_flights_final = pd.read_csv("Data/us_flights_final.csv")
us_passenger_miles_final = pd.read_csv("Data/us_passenger_miles_final.csv")
us_seat_miles_final = pd.read_csv("Data/us_seat_miles_final.csv")
us_load_final = pd.read_csv("Data/us_load_final.csv")

# Delta Airlines Data

dal_passengers_final = pd.read_csv("Data/dal_passengers_final.csv")
dal_flights_final = pd.read_csv("Data/dal_flights_final.csv")
dal_passenger_miles_final = pd.read_csv("Data/dal_passenger_miles_final.csv")
dal_seat_miles_final = pd.read_csv("Data/dal_seat_miles_final.csv")
dal_load_final = pd.read_csv("Data/dal_load_final.csv")


# Southwest Airlines Data

luv_passengers_final = pd.read_csv("Data/luv_passengers_final.csv")
luv_flights_final = pd.read_csv("Data/luv_flights_final.csv")
luv_passenger_miles_final = pd.read_csv("Data/luv_passenger_miles_final.csv")
luv_seat_miles_final = pd.read_csv("Data/luv_seat_miles_final.csv")
luv_load_final = pd.read_csv("Data/luv_load_final.csv")

# United Airlines Data

ual_passengers_final = pd.read_csv("Data/ual_passengers_final.csv")
ual_flights_final = pd.read_csv("Data/ual_flights_final.csv")
ual_passenger_miles_final = pd.read_csv("Data/ual_passenger_miles_final.csv")
ual_seat_miles_final = pd.read_csv("Data/ual_seat_miles_final.csv")
ual_load_final = pd.read_csv("Data/ual_load_final.csv")

# %%
# Prepared Index

# All U.S. Carriers

us_passengers_final.set_index('Year', inplace=True)
us_flights_final.set_index('Year', inplace=True)
us_passenger_miles_final.set_index('Year', inplace=True)
us_seat_miles_final.set_index('Year', inplace=True)
us_load_final.set_index('Year', inplace=True)

# Delta Airlines

dal_passengers_final.set_index('Year', inplace=True)
dal_flights_final.set_index('Year', inplace=True)
dal_passenger_miles_final.set_index('Year', inplace=True)
dal_seat_miles_final.set_index('Year', inplace=True)
dal_load_final.set_index('Year', inplace=True)

# Southwest Airlines

luv_passengers_final.set_index('Year', inplace=True)
luv_flights_final.set_index('Year', inplace=True)
luv_passenger_miles_final.set_index('Year', inplace=True)
luv_seat_miles_final.set_index('Year', inplace=True)
luv_load_final.set_index('Year', inplace=True)

# United Airlines

ual_passengers_final.set_index('Year', inplace=True)
ual_flights_final.set_index('Year', inplace=True)
ual_passenger_miles_final.set_index('Year', inplace=True)
ual_seat_miles_final.set_index('Year', inplace=True)
ual_load_final.set_index('Year', inplace=True)

# %%
# HVPLOT for PANEL (Copied Notes from bt_statistics.ipynb)


# us_passengers_final.hvplot.bar(label="All U.S. Carriers - All Airports", ylabel = "Number of Passengers", width=900,height=500).opts(yformatter="%.0f")
# us_flights_final.hvplot.bar(label="All U.S. Carriers Flights - All Airports", ylabel = "Number of Flights", width=900,height=500).opts(yformatter="%.0f")
# us_passenger_miles_final.hvplot.bar(label="All U.S. Carriers Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# us_seat_miles_final.hvplot.bar(label="All U.S. Carriers Available Seat-Miles - All Airports", ylabel = "Available Seat-miles (the number of seats and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# us_load_final.hvplot.bar(label="All U.S. Carriers Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%))", width=900,height=500).opts(yformatter="%.0f")



# dal_passengers_final.hvplot.bar(label="Delta Airlines - All Airports", ylabel = "Number of Passengers", width=900,height=500).opts(yformatter="%.0f")
# dal_flights_final.hvplot.bar(label="Delta Airlines Flights - All Airports", ylabel = "Number of Flights", width=900,height=500).opts(yformatter="%.0f")
# dal_passenger_miles_final.hvplot.bar(label="Delta Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# dal_seat_miles_final.hvplot.bar(label="Delta Airlines Available Seat-Miles - All Airports", ylabel = "Available Seat-miles (the number of seats and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# dal_load_final.hvplot.bar(label="Delta Airlines Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%))", width=900,height=500).opts(yformatter="%.0f")



# luv_passengers_final.hvplot.bar(label="Southwest Airlines - All Airports", ylabel = "Number of Passengers", width=900,height=500).opts(yformatter="%.0f")
# luv_flights_final.hvplot.bar(label="Southwest Airlines Flights - All Airports", ylabel = "Number of Flights", width=900,height=500).opts(yformatter="%.0f")
# luv_passenger_miles_final.hvplot.bar(label="Southwest Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# luv_seat_miles_final.hvplot.bar(label="Southwest Airlines Available Seat-Miles - All Airports", ylabel = "Available Seat-miles (the number of seats and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# luv_load_final.hvplot.bar(label="Southwest Airlines Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%))", width=900,height=500).opts(yformatter="%.0f")


# ual_passengers_final.hvplot.bar(label="United Airlines - All Airports", ylabel = "Number of Passengers", width=900,height=500).opts(yformatter="%.0f")
# ual_flights_final.hvplot.bar(label="United Airlines Flights - All Airports", ylabel = "Number of Flights", width=900,height=500).opts(yformatter="%.0f")
# ual_passenger_miles_final.hvplot.bar(label="United Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# ual_seat_miles_final.hvplot.bar(label="United Airlines Available Seat-Miles - All Airports", ylabel = "Available Seat-miles (the number of seats and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# ual_load_final.hvplot.bar(label="United Airlines Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%))", width=900,height=500).opts(yformatter="%.0f")

# %%
# Created Function for plots for Passenger Data, Flights, Passenger-Miles, Seat-Miles, and Load data

# Passenger Data

def us_chart1():
    bar_plot = us_passengers_final.hvplot.bar(label= "All U.S. Carriers - All Airports", ylabel = "Number of Passengers", color= "Orange", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def dal_chart1():
    bar_plot = dal_passengers_final.hvplot.bar(label= "Delta Airlines - All Airports", ylabel = "Number of Passengers", color="Green", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def luv_chart1():
    bar_plot = luv_passengers_final.hvplot.bar(label= "Southwest Airlines - All Airports", ylabel = "Number of Passengers", color="Purple",shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def ual_chart1():
    bar_plot = ual_passengers_final.hvplot.bar(label= "United Airlines - All Airports", ylabel = "Number of Passengers", color="Yellow", shared_axes= False  ,width=900,height=500).opts(yformatter="%.0f")
    return bar_plot


# Flights Data

def us_chart2():
    bar_plot = us_flights_final.hvplot.bar(label= "All U.S. Carriers Flights - All Airports", ylabel = "Number of Flights", color="Orange", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def dal_chart2():
    bar_plot = dal_flights_final.hvplot.bar(label= "Delta Airlines Flights - All Airports", ylabel = "Number of Flights", color="Green", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def luv_chart2():
    bar_plot = luv_flights_final.hvplot.bar(label= "Southwest Airlines Flights - All Airports", ylabel = "Number of Flights", color="Purple", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def ual_chart2():
    bar_plot = ual_flights_final.hvplot.bar(label= "United Airlines Flights - All Airports", ylabel = "Number of Flights", color="Yellow", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

# Passenger-Miles Data

def us_chart3():
    bar_plot = us_passenger_miles_final.hvplot.bar(label= "All U.S. Carriers Airlines Revenue Passenger-Miles - All Airports" , ylabel = "(The number of passengers and the distance flown in thousands (000)) ", color="Orange", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def dal_chart3():
    bar_plot = dal_passenger_miles_final.hvplot.bar(label= "Delta Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000)) ", color="Green", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def luv_chart3():
    bar_plot = luv_passenger_miles_final.hvplot.bar(label= "Southwest Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000)) ", color="Purple", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def ual_chart3():
    bar_plot = ual_passenger_miles_final.hvplot.bar(label= "United Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000)) ", color="Yellow", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

# Seat-Miles Data

def us_chart4():
    bar_plot = us_seat_miles_final.hvplot.bar(label= "All U.S. Carriers Available Seat-Miles - All Airports" , ylabel = "(the number of seats and the distance flown in thousands (000)) ", color="Orange", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def dal_chart4():
    bar_plot = dal_seat_miles_final.hvplot.bar(label= "Delta Airlines Available Seat-Miles - All Airports", ylabel = "(the number of seats and the distance flown in thousands (000)) ", color="Green", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def luv_chart4():
    bar_plot = luv_seat_miles_final.hvplot.bar(label= "Southwest Airlines Available Seat-Miles - All Airports", ylabel = "(the number of seats and the distance flown in thousands (000)) ", color="Purple", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def ual_chart4():
    bar_plot = ual_seat_miles_final.hvplot.bar(label= "United Airlines Available Seat-Miles - All Airports", ylabel = "(the number of seats and the distance flown in thousands (000)) ", color="Yellow", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

# Load Factor Data

def us_chart5():
    bar_plot = us_load_final.hvplot.bar(label= "All U.S. Carriers Load Factor - All Airports" , ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%)) ", color="Orange", shared_axes= False , width=900,height=500)
    return bar_plot

def dal_chart5():
    bar_plot = dal_load_final.hvplot.bar(label= "Delta Airlines Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%)) ", color="Green", shared_axes= False , width=900,height=500)
    return bar_plot

def luv_chart5():
    bar_plot = luv_load_final.hvplot.bar(label= "Southwest Airlines Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%)) ", color="Purple", shared_axes= False , width=900,height=500)
    return bar_plot

def ual_chart5():
    bar_plot = ual_load_final.hvplot.bar(label= "United Airlines Load Factor  - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%)) ", color="Yellow", shared_axes= False , width=900,height=500)
    return bar_plot

# %%
# Created variables for dashboard

dashboard_title = " Bureau of Transportation Statistics - Aviation Data"

dashboard_welcome = " The dashboard presents a visual analysis of aviation data from All U.S. Carriers, Delta Airlines, Southwest Airlines, and United Airlines"

dashboard_page = pn.Column(dashboard_title, dashboard_welcome)

passenger_data = pn.Column(pn.Pane(us_chart1()), pn.Pane(dal_chart1()), pn.Pane(luv_chart1()), pn.Pane(ual_chart1()))

flights_data = pn.Column(pn.Pane(us_chart2()), pn.Pane(dal_chart2()), pn.Pane(luv_chart2()), pn.Pane(ual_chart2()))

passenger_miles_data = pn.Column(pn.Pane(us_chart3()), pn.Pane(dal_chart3()), pn.Pane(luv_chart3()), pn.Pane(ual_chart3()))

seat_miles_data = pn.Column(pn.Pane(us_chart4()), pn.Pane(dal_chart4()), pn.Pane(luv_chart4()), pn.Pane(ual_chart4()))

load_data = pn.Column(pn.Pane(us_chart5()), pn.Pane(dal_chart5()), pn.Pane(luv_chart5()), pn.Pane(ual_chart5()))


#Create Dashboard
dashboard_tabs = pn.Tabs(            
                ("Passenger Data", passenger_data),
                ("Flight Data", flights_data),
                ("Revenue Passenger-Miles Data", passenger_miles_data),
                ("Available Seat-Miles", seat_miles_data),
                ("Load Data", load_data)
)

# %%
dashboard_tabs.servable()
# Out:
# Tabs
#     [0] Column
#         [0] HoloViews(Bars)
#         [1] HoloViews(Bars)
#         [2] HoloViews(Bars)
#         [3] HoloViews(Bars)
#     [1] Column
#         [0] HoloViews(Bars)
#         [1] HoloViews(Bars)
#         [2] HoloViews(Bars)
#         [3] HoloViews(Bars)
#     [2] Column
#         [0] HoloViews(Bars)
#         [1] HoloViews(Bars)
#         [2] HoloViews(Bars)
#         [3] HoloViews(Bars)
#     [3] Column
#         [0] HoloViews(Bars)
#         [1] HoloViews(Bars)
#         [2] HoloViews(Bars)
#         [3] HoloViews(Bars)
#     [4] Column
#         [0] HoloViews(Bars)
#         [1] HoloViews(Bars)
#         [2] HoloViews(Bars)
#         [3] HoloViews(Bars)
