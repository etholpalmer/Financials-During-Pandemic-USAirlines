# %%
# Created Library 

import panel as pn
pn.extension('plotly')

import plotly.express as px

import plotly

import pandas as pd

import hvplot.pandas

from matplotlib import pyplot as plt

import os

from pathlib import Path

import numpy as np

from bokeh.plotting import figure, show

from bokeh.io import output_notebook

from holoviews import opts

from bokeh.models.formatters import DatetimeTickFormatter

from bokeh.models.formatters import BasicTickFormatter

import holoviews as hv

from holoviews import opts

# %%
# Imported cleaned csv files in preparation for visualization

# All U.S. Carriers Data

us_passengers_final = pd.read_csv("Data/transportation_statistics(cleaned)/us_passengers_final.csv")
us_flights_final = pd.read_csv("Data/transportation_statistics(cleaned)/us_flights_final.csv")
us_passenger_miles_final = pd.read_csv("Data/transportation_statistics(cleaned)/us_passenger_miles_final.csv")
us_seat_miles_final = pd.read_csv("Data/transportation_statistics(cleaned)/us_seat_miles_final.csv")
us_load_final = pd.read_csv("Data/transportation_statistics(cleaned)/us_load_final.csv")

# Delta Airlines Data

dal_passengers_final = pd.read_csv("Data/transportation_statistics(cleaned)/dal_passengers_final.csv")
dal_flights_final = pd.read_csv("Data/transportation_statistics(cleaned)/dal_flights_final.csv")
dal_passenger_miles_final = pd.read_csv("Data/transportation_statistics(cleaned)/dal_passenger_miles_final.csv")
dal_seat_miles_final = pd.read_csv("Data/transportation_statistics(cleaned)/dal_seat_miles_final.csv")
dal_load_final = pd.read_csv("Data/transportation_statistics(cleaned)/dal_load_final.csv")


# Southwest Airlines Data

luv_passengers_final = pd.read_csv("Data/transportation_statistics(cleaned)/luv_passengers_final.csv")
luv_flights_final = pd.read_csv("Data/transportation_statistics(cleaned)/luv_flights_final.csv")
luv_passenger_miles_final = pd.read_csv("Data/transportation_statistics(cleaned)/luv_passenger_miles_final.csv")
luv_seat_miles_final = pd.read_csv("Data/transportation_statistics(cleaned)/luv_seat_miles_final.csv")
luv_load_final = pd.read_csv("Data/transportation_statistics(cleaned)/luv_load_final.csv")

# United Airlines Data

ual_passengers_final = pd.read_csv("Data/transportation_statistics(cleaned)/ual_passengers_final.csv")
ual_flights_final = pd.read_csv("Data/transportation_statistics(cleaned)/ual_flights_final.csv")
ual_passenger_miles_final = pd.read_csv("Data/transportation_statistics(cleaned)/ual_passenger_miles_final.csv")
ual_seat_miles_final = pd.read_csv("Data/transportation_statistics(cleaned)/ual_seat_miles_final.csv")
ual_load_final = pd.read_csv("Data/transportation_statistics(cleaned)/ual_load_final.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-61eb82ce0ef6> in <module>
#       3 # All U.S. Carriers Data
#       4
# ----> 5 us_passengers_final = pd.read_csv("Data/transportation_statistics(cleaned)/us_passengers_final.csv")
#       6 us_flights_final = pd.read_csv("Data/transportation_statistics(cleaned)/us_flights_final.csv")
#       7 us_passenger_miles_final = pd.read_csv("Data/transportation_statistics(cleaned)/us_passenger_miles_final.csv")
#
# ...

# %%
# Imported airline fundamentals data files

dal_fundamentals = pd.read_csv("Data/DAL_fundamentals.csv")

luv_fundamentals = pd.read_csv("Data/LUV_fundamentals.csv")

ual_fundamentals = pd.read_csv("Data/UAL_fundamentals.csv")

# %%
# Prepared Index

# All U.S. Carriers

us_passengers_final.set_index('Year', inplace=True)
us_flights_final.set_index('Year', inplace=True)
us_passenger_miles_final.set_index('Year', inplace=True)
us_seat_miles_final.set_index('Year', inplace=True)
us_load_final.set_index('Year', inplace=True)

# Delta Airlines

dal_passengers_final.set_index('Year', inplace=True)
dal_flights_final.set_index('Year', inplace=True)
dal_passenger_miles_final.set_index('Year', inplace=True)
dal_seat_miles_final.set_index('Year', inplace=True)
dal_load_final.set_index('Year', inplace=True)

# Southwest Airlines

luv_passengers_final.set_index('Year', inplace=True)
luv_flights_final.set_index('Year', inplace=True)
luv_passenger_miles_final.set_index('Year', inplace=True)
luv_seat_miles_final.set_index('Year', inplace=True)
luv_load_final.set_index('Year', inplace=True)

# United Airlines

ual_passengers_final.set_index('Year', inplace=True)
ual_flights_final.set_index('Year', inplace=True)
ual_passenger_miles_final.set_index('Year', inplace=True)
ual_seat_miles_final.set_index('Year', inplace=True)
ual_load_final.set_index('Year', inplace=True)

# %%
ual_passengers_final

# %%
# HVPLOT for PANEL (Copied Notes from bt_statistics.ipynb)


# us_passengers_final.hvplot.bar(label="All U.S. Carriers - All Airports", ylabel = "Number of Passengers", width=900,height=500).opts(yformatter="%.0f")
# us_flights_final.hvplot.bar(label="All U.S. Carriers Flights - All Airports", ylabel = "Number of Flights", width=900,height=500).opts(yformatter="%.0f")
# us_passenger_miles_final.hvplot.bar(label="All U.S. Carriers Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# us_seat_miles_final.hvplot.bar(label="All U.S. Carriers Available Seat-Miles - All Airports", ylabel = "Available Seat-miles (the number of seats and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# us_load_final.hvplot.bar(label="All U.S. Carriers Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%))", width=900,height=500).opts(yformatter="%.0f")



# dal_passengers_final.hvplot.bar(label="Delta Airlines - All Airports", ylabel = "Number of Passengers", width=900,height=500).opts(yformatter="%.0f")
# dal_flights_final.hvplot.bar(label="Delta Airlines Flights - All Airports", ylabel = "Number of Flights", width=900,height=500).opts(yformatter="%.0f")
# dal_passenger_miles_final.hvplot.bar(label="Delta Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# dal_seat_miles_final.hvplot.bar(label="Delta Airlines Available Seat-Miles - All Airports", ylabel = "Available Seat-miles (the number of seats and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# dal_load_final.hvplot.bar(label="Delta Airlines Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%))", width=900,height=500).opts(yformatter="%.0f")



# luv_passengers_final.hvplot.bar(label="Southwest Airlines - All Airports", ylabel = "Number of Passengers", width=900,height=500).opts(yformatter="%.0f")
# luv_flights_final.hvplot.bar(label="Southwest Airlines Flights - All Airports", ylabel = "Number of Flights", width=900,height=500).opts(yformatter="%.0f")
# luv_passenger_miles_final.hvplot.bar(label="Southwest Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# luv_seat_miles_final.hvplot.bar(label="Southwest Airlines Available Seat-Miles - All Airports", ylabel = "Available Seat-miles (the number of seats and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# luv_load_final.hvplot.bar(label="Southwest Airlines Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%))", width=900,height=500).opts(yformatter="%.0f")


# ual_passengers_final.hvplot.bar(label="United Airlines - All Airports", ylabel = "Number of Passengers", width=900,height=500).opts(yformatter="%.0f")
# ual_flights_final.hvplot.bar(label="United Airlines Flights - All Airports", ylabel = "Number of Flights", width=900,height=500).opts(yformatter="%.0f")
# ual_passenger_miles_final.hvplot.bar(label="United Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# ual_seat_miles_final.hvplot.bar(label="United Airlines Available Seat-Miles - All Airports", ylabel = "Available Seat-miles (the number of seats and the distance flown in thousands (000))", width=900,height=500).opts(yformatter="%.0f")
# ual_load_final.hvplot.bar(label="United Airlines Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%))", width=900,height=500).opts(yformatter="%.0f")

# %%
# Created Function for plots for Passenger Data, Flights, Passenger-Miles, Seat-Miles, and Load data

# Passenger Data
def Make_Chart(data, lbl=None,ylbl=None,color='Orange', shrd__ax=False,size=(900,500),yfmt='%.0f', BarChart=True):
    if BarChart:
        plot = data.hvplot.bar(label= lbl
                        , ylabel= ylbl
                        , color= color
                        , shared_axes= shrd__ax
                        , width=size[0],height=size[1]
                        ).opts(yformatter=yfmt)
    else:
        plot = data.hvplot.line(label= lbl
                        , ylabel= ylbl
                        , color= color
                        , shared_axes= shrd__ax
                        , width=size[0],height=size[1]
                        ).opts(yformatter=yfmt)

    return plot

chart_list = [  (us_passengers_final,"All U.S.Carriers Passengers - All Airports", "Number of Passengers")
                , (dal_passengers_final, "Delta Airlines Passengers - All Airports", "Number of Passengers")
                , (luv_passengers_final, "Southwest Airlines Passengers - All Airports", "Number of Passengers")
                , (ual_passengers_final, "United Airlines Passengers - All Airports",  "Number of Passengers")]
passenger_lst = []
for dta, lbl, ylbl in chart_list:
    cht = Make_Chart(data=dta, lbl=lbl, ylbl=ylbl,BarChart=False)
    passenger_lst.append(cht)

# Make_Chart(data=us_passengers_final, lbl= "All U.S.Carriers Passengers - All Airports", ylbl = "Number of Passengers")
# Make_Chart(data=dal_passengers_final, lbl= "Delta Airlines Passengers - All Airports", ylbl = "Number of Passengers")
# Make_Chart(data=luv_passengers_final, lbl= "Southwest Airlines Passengers - All Airports", ylbl = "Number of Passengers")
# Make_Chart(data=ual_passengers_final, lbl= "United Airlines Passengers - All Airports", ylbl = "Number of Passengers")
# Out:
# :Curve   [Year]   (TOTAL)

# %%
# Flights Data

def us_chart2():
    bar_plot = us_flights_final.hvplot.bar(label= "All U.S. Carriers Flights - All Airports", ylabel = "Number of Flights", color="Green", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def dal_chart2():
    bar_plot = dal_flights_final.hvplot.bar(label= "Delta Airlines Flights - All Airports", ylabel = "Number of Flights", color="Green", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def luv_chart2():
    bar_plot = luv_flights_final.hvplot.bar(label= "Southwest Airlines Flights - All Airports", ylabel = "Number of Flights", color="Green", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def ual_chart2():
    bar_plot = ual_flights_final.hvplot.bar(label= "United Airlines Flights - All Airports", ylabel = "Number of Flights", color="Green", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

# Passenger-Miles Data

def us_chart3():
    bar_plot = us_passenger_miles_final.hvplot.bar(label= "All U.S. Carriers Airlines Revenue Passenger-Miles - All Airports" , ylabel = "(The number of passengers and the distance flown in thousands (000)) ", color="Yellow", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def dal_chart3():
    bar_plot = dal_passenger_miles_final.hvplot.bar(label= "Delta Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000)) ", color="Yellow", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def luv_chart3():
    bar_plot = luv_passenger_miles_final.hvplot.bar(label= "Southwest Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000)) ", color="Yellow", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def ual_chart3():
    bar_plot = ual_passenger_miles_final.hvplot.bar(label= "United Airlines Revenue Passenger-Miles - All Airports", ylabel = "(The number of passengers and the distance flown in thousands (000)) ", color="Yellow", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

# Seat-Miles Data

def us_chart4():
    bar_plot = us_seat_miles_final.hvplot.bar(label= "All U.S. Carriers Available Seat-Miles - All Airports" , ylabel = "(the number of seats and the distance flown in thousands (000)) ", color="Purple", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def dal_chart4():
    bar_plot = dal_seat_miles_final.hvplot.bar(label= "Delta Airlines Available Seat-Miles - All Airports", ylabel = "(the number of seats and the distance flown in thousands (000)) ", color="Purple", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def luv_chart4():
    bar_plot = luv_seat_miles_final.hvplot.bar(label= "Southwest Airlines Available Seat-Miles - All Airports", ylabel = "(the number of seats and the distance flown in thousands (000)) ", color="Purple", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

def ual_chart4():
    bar_plot = ual_seat_miles_final.hvplot.bar(label= "United Airlines Available Seat-Miles - All Airports", ylabel = "(the number of seats and the distance flown in thousands (000)) ", color="Purple", shared_axes= False , width=900,height=500).opts(yformatter="%.0f")
    return bar_plot

# Load Factor Data

def us_chart5():
    bar_plot = us_load_final.hvplot.bar(label= "All U.S. Carriers Load Factor - All Airports" , ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%)) ", color="Pink", shared_axes= False , width=900,height=500)
    return bar_plot

def dal_chart5():
    bar_plot = dal_load_final.hvplot.bar(label= "Delta Airlines Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%)) ", color="Pink", shared_axes= False , width=900,height=500)
    return bar_plot

def luv_chart5():
    bar_plot = luv_load_final.hvplot.bar(label= "Southwest Airlines Load Factor - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%)) ", color="Pink", shared_axes= False , width=900,height=500)
    return bar_plot

def ual_chart5():
    bar_plot = ual_load_final.hvplot.bar(label= "United Airlines Load Factor  - All Airports", ylabel = "(passenger-miles as a proportion of available seat-miles in percent (%)) ", color="Pink", shared_axes= False , width=900,height=500)
    return bar_plot

# %%
# Created Variables for dashboard
x_page = pn.Row(lst[0], lst[1],lst[2],lst[3],)
us_page = pn.Row(us_chart1(), us_chart2(), us_chart3(), us_chart4(), us_chart5())

dal_page = pn.Row(dal_chart1(), dal_chart2(), dal_chart3(), dal_chart4(), dal_chart5())

luv_page = pn.Row(luv_chart1(), luv_chart2(), luv_chart3(), luv_chart4(), luv_chart5())

ual_page = pn.Row(ual_chart1(), ual_chart2(), ual_chart3(), ual_chart4(), ual_chart5())

# Dashboard tabs

dashboard_tabs = pn.Tabs(
    ("Test Page", x_page),
    ("Industry Analysis", us_page),
    ("Delta Airlines", dal_page),
    ("Southwest Airlines", luv_page),
    ("United Airlines", ual_page)
)

# %%
dashboard_tabs.servable()
# Out:
# Tabs
#     [0] Row
#         [0] HoloViews(Curve)
#         [1] HoloViews(Curve)
#         [2] HoloViews(Curve)
#         [3] HoloViews(Curve)
#     [1] Row
#         [0] HoloViews(Bars)
#         [1] HoloViews(Bars)
#         [2] HoloViews(Bars)
#         [3] HoloViews(Bars)
#         [4] HoloViews(Bars)
#     [2] Row
#         [0] HoloViews(Bars)
#         [1] HoloViews(Bars)
#         [2] HoloViews(Bars)
#         [3] HoloViews(Bars)
#         [4] HoloViews(Bars)
#     [3] Row
#         [0] HoloViews(Bars)
#         [1] HoloViews(Bars)
#         [2] HoloViews(Bars)
#         [3] HoloViews(Bars)
#         [4] HoloViews(Bars)
#     [4] Row
#         [0] HoloViews(Bars)
#         [1] HoloViews(Bars)
#         [2] HoloViews(Bars)
#         [3] HoloViews(Bars)
#         [4] HoloViews(Bars)

# %%
# Created variables for dashboard

welcomda_notes = " Bureau of Transportation Statistics - Aviation Data"

dashboard_welcome = " The dashboard presents a visual analysis of aviation data from All U.S. Carriers, Delta Airlines, Southwest Airlines, and United Airlines"


passenger_miles_notes = "According to the Bureau of Transportation Statistics (2021), A revenue passenger mile (RPM) is a transportation industry metric that shows the number of miles traveled by paying passengers and is typically an airline traffic statistic. Revenue passenger miles are calculated by multiplying the number of paying passengers by the distance traveled. For example, an airplane with 100 passengers that flies 250 miles has generated 25,000 RPM." 

passenger_miles_notes2 = "Revenue passenger miles are the backbone of most transportation metrics. RPM is often compared to available seat miles (ASM), a measure of an airplane's total carrying capacity available to generate income. By dividing RPM by ASM, an airline can calculate load factors. The load factor is a percentage indicating how effective the airline is at selling seats and earning revenue. Higher load factors, obviously, are desired because empty seats are an opportunity cost for an airline. "


seat_notes = "According to Investopedia (2020), available seat miles (ASM) is a measure of an airplane's carrying capacity available to generate revenues. Available seat miles refers to how many seat miles are actually available for purchase on an airline. Seat miles are calculated by multiplying the number of miles that a given airplane will be flying by the number of seats available for a given flight. "


load_notes = "According to the Air Transport Association (2020) , A high load factor indicates that an airline has full planes with most seats occupied by passengers. Airlines have high fixed costs associated with each flight. Every flight must have an entire flight crew and support staff, a well-maintained aircraft with enough fuel, and services that entertain and comfort customers. The load factor help investors understand how the airline covers expenses and generates a profit. A low load factor may be a cause for concern and may indicate an unprofitable airline."

# %%
# DO NOT PUSH TO GIT!
