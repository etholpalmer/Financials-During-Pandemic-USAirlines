# %% [markdown]
# # Stock information

# %% [markdown]
# ## Configuration

# %%
import os
import requests
from dotenv import load_dotenv
import pandas as pd
import csv as csv
import alpaca_trade_api as tradeapi

# %%
if load_dotenv():
    print('The environment variables have been loaded')
# Out:
# The environment variables have been loaded

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")
if type(alpaca_secret_key) == str:
    print('The Alpaca Key has been loded')
# Out:
# The Alpaca Key has been loded

# %%
# Create the Alpaca API object
api=tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2"
)

# %% [markdown]
# ## Data Gathering

# %% [markdown]
# ### Daily

# %%
tickers=["LUV","DAL","UAL","AAL"]
timeframe="1D"

# %%
start_date1=pd.Timestamp("2011-01-01",tz="America/New_York").isoformat()
end_date1=pd.Timestamp("2014-01-01",tz="America/New_York").isoformat()

# %%
df_stock_data1=api.get_barset(
        tickers,
        timeframe,
        start=start_date1,
        end=end_date1,
        limit=1000

).df

# %%
df_stock_data1.tail()
# Out:
#                              AAL                                     DAL  \
#                             open   high    low  close      volume   open
# time
# 2013-12-24 00:00:00-05:00  25.10  25.35  25.10  25.34   2649655.0  27.59
# 2013-12-26 00:00:00-05:00  25.23  26.24  25.09  25.22   4222854.0  27.86
# 2013-12-27 00:00:00-05:00  25.04  25.40  24.23  24.95  12170869.0  27.86
# 2013-12-30 00:00:00-05:00  24.87  25.25  23.79  23.92   8346135.0  25.19
# 2013-12-31 00:00:00-05:00  23.89  25.10  23.78  24.37   6763856.0  27.23
#
#                                                            LUV         \
#                             high    low  close   volume   open   high
# time
# 2013-12-24 00:00:00-05:00  27.92  27.51  27.83  4732890  18.87  18.95
# 2013-12-26 00:00:00-05:00  27.98  27.59  27.88  5895605  18.94  18.97
# 2013-12-27 00:00:00-05:00  27.89  25.26  25.29  9891263  18.98  19.00
# 2013-12-30 00:00:00-05:00  27.27  25.17  27.18  7492521  18.80  18.92
# 2013-12-31 00:00:00-05:00  27.65  25.57  27.48  8597788  18.84  18.94
#
#                                                       UAL                  \
#                                low  close   volume   open   high      low
# time
# 2013-12-24 00:00:00-05:00  18.8001  18.92  1368265  36.96  37.83  36.7014
# 2013-12-26 00:00:00-05:00  18.8000  18.94  2218450  37.91  38.33  37.6100
# 2013-12-27 00:00:00-05:00  18.6000  18.74  2646107  38.07  38.11  36.5642
# 2013-12-30 00:00:00-05:00  18.7400  18.82  2734486  36.88  37.43  36.7900
# 2013-12-31 00:00:00-05:00  18.7600  18.85  2287036  37.43  37.90  37.3500
#
#
#                            close   volume
# time
# 2013-12-24 00:00:00-05:00  37.61  1770877
# 2013-12-26 00:00:00-05:00  38.06  2338556
# 2013-12-27 00:00:00-05:00  36.78  3069946
# 2013-12-30 00:00:00-05:00  37.29  2344354
# 2013-12-31 00:00:00-05:00  37.82  1658030

# %%
start_date1=pd.Timestamp("2014-01-01",tz="America/New_York").isoformat()
end_date1=pd.Timestamp("2018-01-01",tz="America/New_York").isoformat()

df_stock_data2=api.get_barset(
        tickers,
        timeframe,
        start=start_date1,
        end=end_date1,
        limit=1000

).df

# %%
df_stock_data2.tail()
# Out:
#                              AAL                                   DAL  \
#                             open    high    low  close   volume   open
# time
# 2017-12-22 00:00:00-05:00  52.49  52.710  52.19  52.60  1998570  56.17
# 2017-12-26 00:00:00-05:00  52.35  53.215  52.33  52.86  2262980  55.90
# 2017-12-27 00:00:00-05:00  52.60  52.680  51.86  52.38  2171344  55.72
# 2017-12-28 00:00:00-05:00  52.45  52.630  52.01  52.45  1313775  56.18
# 2017-12-29 00:00:00-05:00  52.42  52.820  51.78  51.81  1845272  56.53
#
#                                                             LUV           \
#                              high    low  close   volume   open     high
# time
# 2017-12-22 00:00:00-05:00  56.225  55.87  56.04  2982542  66.30  66.3200
# 2017-12-26 00:00:00-05:00  56.555  55.65  55.77  2670149  65.76  66.3302
# 2017-12-27 00:00:00-05:00  56.130  55.27  56.12  3148136  65.94  66.0000
# 2017-12-28 00:00:00-05:00  56.510  55.35  56.34  3221229  66.00  66.0200
# 2017-12-29 00:00:00-05:00  56.690  55.99  56.01  2335872  66.00  66.0750
#
#                                                     UAL                  \
#                              low  close   volume   open   high      low
# time
# 2017-12-22 00:00:00-05:00  65.56  65.98  1759489  67.44  67.48  67.1100
# 2017-12-26 00:00:00-05:00  65.76  65.98  1688020  66.94  67.72  66.4810
# 2017-12-27 00:00:00-05:00  65.56  65.95  1282974  67.62  67.62  66.6101
# 2017-12-28 00:00:00-05:00  65.51  65.87  1570332  67.12  67.57  66.8800
# 2017-12-29 00:00:00-05:00  65.44  65.47  1383890  67.68  67.99  67.3700
#
#
#                            close   volume
# time
# 2017-12-22 00:00:00-05:00  67.26  1833866
# 2017-12-26 00:00:00-05:00  67.36  2065639
# 2017-12-27 00:00:00-05:00  67.11  2395282
# 2017-12-28 00:00:00-05:00  67.54  2135708
# 2017-12-29 00:00:00-05:00  67.41  2616997

# %%
start_date1=pd.Timestamp("2018-01-01",tz="America/New_York").isoformat()
end_date1=pd.Timestamp("2021-06-25",tz="America/New_York").isoformat()

df_stock_data3=api.get_barset(
        tickers,
        timeframe,
        start=start_date1,
        end=end_date1,
        limit=1000

).df

# %%
df_stock_data3.tail()
# Out:
#                              AAL                                      DAL  \
#                             open    high     low   close    volume   open
# time
# 2021-06-21 00:00:00-04:00  22.31  22.545  21.910  22.440  24593683  45.04
# 2021-06-22 00:00:00-04:00  22.36  22.380  21.845  22.115  21136698  45.79
# 2021-06-23 00:00:00-04:00  22.18  22.335  22.080  22.210  16208704  45.39
# 2021-06-24 00:00:00-04:00  22.22  22.500  21.950  22.340  21493037  45.45
# 2021-06-25 00:00:00-04:00  22.37  22.480  22.070  22.230  16422125  44.93
#
#                                                                 LUV         \
#                               high      low  close    volume   open   high
# time
# 2021-06-21 00:00:00-04:00  45.7800  44.8200  45.77   8810120  55.30  56.47
# 2021-06-22 00:00:00-04:00  45.7900  44.8700  45.37   7595685  56.10  56.32
# 2021-06-23 00:00:00-04:00  45.6124  45.0100  45.28   6708487  55.50  55.72
# 2021-06-24 00:00:00-04:00  45.6400  44.5900  44.91   8509432  55.53  55.62
# 2021-06-25 00:00:00-04:00  44.9830  44.2623  44.43  10202665  54.69  54.87
#
#                                                     UAL                       \
#                              low  close   volume   open   high    low  close
# time
# 2021-06-21 00:00:00-04:00  55.29  56.29  4469721  55.24  55.88  54.55  55.69
# 2021-06-22 00:00:00-04:00  55.41  55.76  4052907  55.45  55.57  54.10  55.16
# 2021-06-23 00:00:00-04:00  54.98  55.19  5516595  55.10  55.49  54.90  55.13
# 2021-06-24 00:00:00-04:00  54.62  54.66  7391613  55.11  55.39  53.96  54.34
# 2021-06-25 00:00:00-04:00  54.23  54.56  5044317  54.55  54.57  53.72  53.87
#
#
#                              volume
# time
# 2021-06-21 00:00:00-04:00   9151945
# 2021-06-22 00:00:00-04:00   8933197
# 2021-06-23 00:00:00-04:00   9162760
# 2021-06-24 00:00:00-04:00  10500410
# 2021-06-25 00:00:00-04:00  10472560

# %%
airline_stock=pd.concat([df_stock_data1,df_stock_data2,df_stock_data3])

# %%
airline_stock.shape
# Out:
# (2631, 20)

# %%
airline_stock.head()
# Out:
#                            AAL                           DAL                  \
#                           open high low close volume    open    high     low
# time
# 2011-01-03 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  11.821  11.970  11.616
# 2011-01-04 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  11.728  12.620  11.653
# 2011-01-05 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  12.650  13.210  12.580
# 2011-01-06 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  12.930  13.050  11.997
# 2011-01-07 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  12.007  12.165  11.923
#
#                                                LUV                        \
#                             close    volume   open   high     low  close
# time
# 2011-01-03 00:00:00-05:00  11.709  15516315  13.03  13.29  13.015  13.23
# 2011-01-04 00:00:00-05:00  12.510  19279694  13.20  13.33  13.140  13.30
# 2011-01-05 00:00:00-05:00  12.990  22784285  13.25  13.59  13.200  13.32
# 2011-01-06 00:00:00-05:00  12.016  12404176  13.32  13.36  13.140  13.16
# 2011-01-07 00:00:00-05:00  12.100  12161809  13.22  13.37  13.170  13.29
#
#                                       UAL
#                             volume   open   high    low    close   volume
# time
# 2011-01-03 00:00:00-05:00  4437954  24.13  25.15  24.10  25.1200  6402668
# 2011-01-04 00:00:00-05:00  4667784  25.30  25.92  25.20  25.5299  6701681
# 2011-01-05 00:00:00-05:00  6323679  25.53  26.23  25.25  25.3600  7431922
# 2011-01-06 00:00:00-05:00  6159166  25.43  25.90  25.25  25.7500  5463905
# 2011-01-07 00:00:00-05:00  4577469  25.75  26.08  25.45  25.9400  4215392

# %% [markdown]
# ### Quarterly

# %% [markdown]
# AAL is missing over 700 rows

# %%
df_stock_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 754 entries, 2011-01-03 00:00:00-05:00 to 2013-12-31 00:00:00-05:00
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (AAL, open)    16 non-null     float64
#  1   (AAL, high)    16 non-null     float64
#  2   (AAL, low)     16 non-null     float64
#  3   (AAL, close)   16 non-null     float64
#  4   (AAL, volume)  16 non-null     float64
#  5   (DAL, open)    754 non-null    float64
#  6   (DAL, high)    754 non-null    float64
#  7   (DAL, low)     754 non-null    float64
#  8   (DAL, close)   754 non-null    float64
#  9   (DAL, volume)  754 non-null    int64
#  10  (LUV, open)    754 non-null    float64
#  11  (LUV, high)    754 non-null    float64
#  12  (LUV, low)     754 non-null    float64
#  13  (LUV, close)   754 non-null    float64
#  14  (LUV, volume)  754 non-null    int64
#  15  (UAL, open)    754 non-null    float64
#  16  (UAL, high)    754 non-null    float64
#  17  (UAL, low)     754 non-null    float64
#  18  (UAL, close)   754 non-null    float64
#  19  (UAL, volume)  754 non-null    int64
# dtypes: float64(17), int64(3)
# memory usage: 123.7 KB

# %% [markdown]
# This Code takes the average of all the values and groups the dates into Quarters

# %%
airline_stock_qtr = airline_stock.resample('QS').mean()

# %%
airline_stock_qtr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 42 entries, 2011-01-01 00:00:00-05:00 to 2021-04-01 00:00:00-04:00
# Freq: QS-JAN
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (AAL, open)    31 non-null     float64
#  1   (AAL, high)    31 non-null     float64
#  2   (AAL, low)     31 non-null     float64
#  3   (AAL, close)   31 non-null     float64
#  4   (AAL, volume)  31 non-null     float64
#  5   (DAL, open)    42 non-null     float64
#  6   (DAL, high)    42 non-null     float64
#  7   (DAL, low)     42 non-null     float64
#  8   (DAL, close)   42 non-null     float64
#  9   (DAL, volume)  42 non-null     float64
#  10  (LUV, open)    42 non-null     float64
#  11  (LUV, high)    42 non-null     float64
#  12  (LUV, low)     42 non-null     float64
#  13  (LUV, close)   42 non-null     float64
#  14  (LUV, volume)  42 non-null     float64
#  15  (UAL, open)    42 non-null     float64
#  16  (UAL, high)    42 non-null     float64
#  17  (UAL, low)     42 non-null     float64
#  18  (UAL, close)   42 non-null     float64
#  19  (UAL, volume)  42 non-null     float64
# dtypes: float64(20)
# memory usage: 6.9 KB

# %%
airline_stock_qtr.head()
# Out:
#                            AAL                              DAL             \
#                           open high low close volume       open       high
# time
# 2011-01-01 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  11.024532  11.416116
# 2011-04-01 00:00:00-04:00  NaN  NaN NaN   NaN    NaN   9.744524  10.062057
# 2011-07-01 00:00:00-04:00  NaN  NaN NaN   NaN    NaN   7.768752   8.015078
# 2011-10-01 00:00:00-04:00  NaN  NaN NaN   NaN    NaN   8.002381   8.289619
# 2012-01-01 00:00:00-05:00  NaN  NaN NaN   NaN    NaN   9.541855   9.879337
#
#                                                                      LUV  \
#                                  low      close        volume       open
# time
# 2011-01-01 00:00:00-05:00  10.624887  11.008461  1.780397e+07  12.415000
# 2011-04-01 00:00:00-04:00   9.398016   9.732794  1.563881e+07  11.680238
# 2011-07-01 00:00:00-04:00   7.424241   7.753981  1.467319e+07   9.197031
# 2011-10-01 00:00:00-04:00   7.663598   7.998611  1.172269e+07   8.309365
# 2012-01-01 00:00:00-05:00   9.181600   9.560661  1.197796e+07   8.958387
#
#                                                                           \
#                                 high        low      close        volume
# time
# 2011-01-01 00:00:00-05:00  12.561290  12.258789  12.402144  7.578123e+06
# 2011-04-01 00:00:00-04:00  11.797698  11.555000  11.662538  8.935567e+06
# 2011-07-01 00:00:00-04:00   9.329608   9.015800   9.145234  1.048084e+07
# 2011-10-01 00:00:00-04:00   8.444317   8.161910   8.307776  7.918982e+06
# 2012-01-01 00:00:00-05:00   9.062784   8.817408   8.940669  6.046227e+06
#
#                                  UAL                                   \
#                                 open       high        low      close
# time
# 2011-01-01 00:00:00-05:00  24.791613  25.306790  24.315805  24.778368
# 2011-04-01 00:00:00-04:00  23.381508  23.822014  22.946525  23.350222
# 2011-07-01 00:00:00-04:00  19.326484  19.753844  18.814000  19.258125
# 2011-10-01 00:00:00-04:00  19.108548  19.504381  18.632379  19.073811
# 2012-01-01 00:00:00-05:00  20.829758  21.299784  20.457177  20.881166
#
#
#                                  volume
# time
# 2011-01-01 00:00:00-05:00  6.762292e+06
# 2011-04-01 00:00:00-04:00  7.071027e+06
# 2011-07-01 00:00:00-04:00  6.858209e+06
# 2011-10-01 00:00:00-04:00  5.282887e+06
# 2012-01-01 00:00:00-05:00  6.356818e+06

# %%
pd.Period('2011-03-31', freq='Q'), pd.Period('2011-04-1', freq='Q')
# Out:
# (Period('2011Q1', 'Q-DEC'), Period('2011Q2', 'Q-DEC'))

# %%
# Investigating a way to create a grouping for the date ranges to match the financials
from datetime import datetime
t = datetime.strptime('2009-12-31', '%Y-%m-%d')
pd.PeriodIndex(['2000Q1', '2002Q3'], dtype='period[Q-DEC]', freq='Q-DEC')
#pd.PeriodIndex(t, freq='Q')
tx = pd.Period(t,freq='Q')
(tx,tx.qyear,tx.quarter)
# Out:
# (Period('2009Q4', 'Q-DEC'), 2009, 4)

# %%
from datetime import datetime
def Get_Qtr(xdate:datetime):
    """ This function takes various datetime objects and returns the Quarter associated with the values passed in
        So for an array, it will return an array of quarters as string.  If a single value was passed the
        a single quarter will be returned."""

    import numpy as np
    typ = type(xdate)
    if typ is datetime or typ is datetime.date:
        q = (xdate.month+2)//3
        y = xdate.year
        return (f"{y}Q{q}")
    elif typ is np.ndarray:
        lst_date = [Get_Qtr(x) for x in xdate]
        return lst_date
    elif typ is pd.Series or typ is list:
        lst_date = [Get_Qtr(x[1]) for x in xdate.iteritems()]
        return lst_date
    elif typ is pd.core.indexes.multi.MultiIndex:
        lst_date = [Get_Qtr(x[1].date()) for x in xdate.values]
        return lst_date
    elif typ is pd.core.indexes.datetimes.DatetimeIndex:
        lst_date = [Get_Qtr(x.date()) for x in xdate]
        return lst_date
    else:
        #print(f'The type is {type(xdate)} not planned for.')
        d = xdate
        q = (d.month+2)//3
        y = d.year
        return (f"{y}Q{q}")

# Get_Qtr('2012-12-2'),
Get_Qtr(datetime(2012,12,2))
# Out:
# '2012Q4'

# %%
lst_idx  = [(x[0])        for x in airline_stock_qtr['timeX'].iteritems()]
lst_date = [Get_Qtr(x[1]) for x in airline_stock_qtr['timeX'].iteritems()]
#list(map(Get_Qtr, lst_date))

#Get_Qtr(airline_stock_qtr['timeX'])
#pd.Series(data=lst_date, index=lst_idx, name='timeX')
#airline_stock_qtr['Qtr'] = 
#Get_Qtr(airline_stock_qtr.index.date)
#airline_stock_qtr.head(20)
#[Get_Qtr(x) for x in airline_stock_qtr.index.date]

# %%
#Get_Qtr(airline_stock_qtr['timeX'])
#list(map(Get_Qtr, airline_stock_qtr['timeX'].iteritems()))
#[(x[1]) for x in airline_stock_qtr['timeX'].iteritems()]
#Get_Qtr(airline_stock_qtr['timeX'])
#Get_Qtr(lst[1])
#list(map(Get_Qtr,))

# %%
#airline_stock_qtr['Qtr'] = Get_Qtr(airline_stock_qtr.index.date)
# airline_stock_qtr['timex'] = pd.to_datetime(airline_stock_qtr.index)
# airline_stock_qtr['Qtr'] = Get_Qtr(airline_stock_qtr['timex'])
#airline_stock_qtr.head(2)
# def Conv_dt64_Datetime(dt64):
#     from datetime import datetime
#     import numpy as np
#     ts = (dt64.date - np.datetime64('1970-01-01')) / np.timedelta64(1, 's')
#     return datetime.utcfromtimestamp(ts)

#Conv_dt64_Datetime(airline_stock_qtr.index)

# %% [markdown]
# # The Company Fundamentals

# %%
import pandas as pd
import simfin as sf
import numpy as np
# %matplotlib inline

# %%
sf.set_data_dir('./Data/')      # Changed from '~/Data/' Data in the home directory

# %%
sf.set_api_key(api_key='free')

# %%
# %%time
market = 'us'
df_income = sf.load_income(variant='quarterly', market=market)
df_bal_sheet =sf.load_balance(variant='quarterly', market=market)
# Out:
# Dataset "us-income-quarterly" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "us-balance-quarterly" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Wall time: 11.8 s

# %%
# Add the Quarterly Data

#[x[1].date() for x in df_bal_sheet.index.values]
#type(df_bal_sheet.index) == pd.core.indexes.multi.MultiIndex
#Get_Qtr(df_bal_sheet.index)

df_bal_sheet['Qtr'] = Get_Qtr(df_bal_sheet.index)
df_income['Qtr'] = Get_Qtr(df_income.index)

# %%
tickers = ["LUV","DAL","UAL"]
df_bal_sheet.head()
# Out:
#                     SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# Ticker Report Date
# A      2010-07-31      45846      USD         2010            Q3   2010-10-06
#        2010-10-31      45846      USD         2010            Q4   2010-12-20
#        2011-01-31      45846      USD         2011            Q1   2011-03-09
#        2011-04-30      45846      USD         2011            Q2   2011-06-07
#        2011-07-31      45846      USD         2011            Q3   2011-09-07
#
#                    Restated Date  Shares (Basic)  Shares (Diluted)  \
# Ticker Report Date
# A      2010-07-31     2010-10-06     347000000.0       352000000.0
#        2010-10-31     2011-12-16     344000000.0       356000000.0
#        2011-01-31     2011-03-09     347000000.0       355000000.0
#        2011-04-30     2011-06-07     347000000.0       355000000.0
#        2011-07-31     2011-09-07     348000000.0       357000000.0
#
#                     Cash, Cash Equivalents & Short Term Investments  \
# Ticker Report Date
# A      2010-07-31                                      2.317000e+09
#        2010-10-31                                      2.649000e+09
#        2011-01-31                                      2.638000e+09
#        2011-04-30                                      2.975000e+09
#        2011-07-31                                      3.101000e+09
#
#                     Accounts & Notes Receivable  ...  \
# Ticker Report Date                               ...
# A      2010-07-31                   790000000.0  ...
#        2010-10-31                   869000000.0  ...
#        2011-01-31                   854000000.0  ...
#        2011-04-30                   918000000.0  ...
#        2011-07-31                   917000000.0  ...
#
#                     Total Current Liabilities  Long Term Debt  \
# Ticker Report Date
# A      2010-07-31                2.917000e+09    2.177000e+09
#        2010-10-31                3.083000e+09    2.190000e+09
#        2011-01-31                1.406000e+09    2.138000e+09
#        2011-04-30                1.592000e+09    2.144000e+09
#        2011-07-31                1.505000e+09    2.168000e+09
#
#                     Total Noncurrent Liabilities  Total Liabilities  \
# Ticker Report Date
# A      2010-07-31                   3.373000e+09         6290000000
#        2010-10-31                   3.377000e+09         6460000000
#        2011-01-31                   3.299000e+09         4705000000
#        2011-04-30                   3.096000e+09         4688000000
#        2011-07-31                   3.048000e+09         4553000000
#
#                     Share Capital & Additional Paid-In Capital  \
# Ticker Report Date
# A      2010-07-31                                 7.861000e+09
#        2010-10-31                                 7.910000e+09
#        2011-01-31                                 8.066000e+09
#        2011-04-30                                 8.146000e+09
#        2011-07-31                                 8.254000e+09
#
#                     Treasury Stock  Retained Earnings  Total Equity  \
# Ticker Report Date
# A      2010-07-31    -7.986000e+09       3.152000e+09  2.810000e+09
#        2010-10-31    -8.038000e+09       3.444000e+09  3.236000e+09
#        2011-01-31    -8.308000e+09       3.637000e+09  3.339000e+09
#        2011-04-30    -8.308000e+09       3.837000e+09  3.961000e+09
#        2011-07-31    -8.500000e+09       4.167000e+09  4.200000e+09
#
#                     Total Liabilities & Equity     Qtr
# Ticker Report Date
# A      2010-07-31                   9100000000  2010Q3
#        2010-10-31                   9696000000  2010Q4
#        2011-01-31                   8044000000  2011Q1
#        2011-04-30                   8649000000  2011Q2
#        2011-07-31                   8753000000  2011Q3
#
# [5 rows x 29 columns]

# %%
airline_income_df=df_income.loc[tickers].reset_index()
airline_balsheet_df=df_bal_sheet.loc[tickers].reset_index()

# %%
airline_balsheet_df.columns
# Out:
# Index(['Ticker', 'Report Date', 'SimFinId', 'Currency', 'Fiscal Year',
#        'Fiscal Period', 'Publish Date', 'Restated Date', 'Shares (Basic)',
#        'Shares (Diluted)', 'Cash, Cash Equivalents & Short Term Investments',
#        'Accounts & Notes Receivable', 'Inventories', 'Total Current Assets',
#        'Property, Plant & Equipment, Net',
#        'Long Term Investments & Receivables', 'Other Long Term Assets',
#        'Total Noncurrent Assets', 'Total Assets', 'Payables & Accruals',
#        'Short Term Debt', 'Total Current Liabilities', 'Long Term Debt',
#        'Total Noncurrent Liabilities', 'Total Liabilities',
#        'Share Capital & Additional Paid-In Capital', 'Treasury Stock',
#        'Retained Earnings', 'Total Equity', 'Total Liabilities & Equity',
#        'Qtr'],
#       dtype='object')

# %%
airline_income_df.columns
# Out:
# Index(['Ticker', 'Report Date', 'SimFinId', 'Currency', 'Fiscal Year',
#        'Fiscal Period', 'Publish Date', 'Restated Date', 'Shares (Basic)',
#        'Shares (Diluted)', 'Revenue', 'Cost of Revenue', 'Gross Profit',
#        'Operating Expenses', 'Selling, General & Administrative',
#        'Research & Development', 'Depreciation & Amortization',
#        'Operating Income (Loss)', 'Non-Operating Income (Loss)',
#        'Interest Expense, Net', 'Pretax Income (Loss), Adj.',
#        'Abnormal Gains (Losses)', 'Pretax Income (Loss)',
#        'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations',
#        'Net Extraordinary Gains (Losses)', 'Net Income', 'Net Income (Common)',
#        'Qtr'],
#       dtype='object')

# %%
airline_ratios=pd.DataFrame()

# %%
airline_ratios=airline_balsheet_df[['Ticker','Report Date','Fiscal Year','Fiscal Period','Cash, Cash Equivalents & Short Term Investments','Qtr']]

# %%
#calculating Balance Sheet Ratio
airline_balsheet_df['Quick Ratio']=(airline_balsheet_df['Total Current Assets']-airline_balsheet_df['Inventories'])/airline_balsheet_df['Total Current Liabilities']
airline_balsheet_df['Current Ratio']=airline_balsheet_df['Total Current Assets']/airline_balsheet_df['Total Current Liabilities']
airline_balsheet_df['Debt-to-Equity Ratio']=airline_balsheet_df['Total Liabilities']/airline_balsheet_df['Total Equity']
airline_balsheet_df['Long Term Debt-to-Equity Ratio']=airline_balsheet_df['Long Term Debt']/airline_balsheet_df['Total Equity']
airline_balsheet_df['Short Term Debt-to-Equity Ratio']=airline_balsheet_df['Short Term Debt']/airline_balsheet_df['Total Equity']

# %%
#calculating income statement ratios
airline_income_df["Gross Profit Margin"]=airline_income_df['Gross Profit']/airline_income_df['Revenue']
airline_income_df["Net Profit Margin"]=airline_income_df['Net Income']/airline_income_df['Revenue']
airline_income_df["Operating Margin"]=airline_income_df['Operating Income (Loss)']/airline_income_df['Revenue']
airline_income_df['EPS']=airline_income_df['Net Income']/airline_income_df['Shares (Basic)']
airline_income_df['Interest Coverage Ratio']=airline_income_df['Net Income']/airline_income_df['Shares (Basic)']

# %%
airline_balsheet_df.head()
# Out:
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 0    LUV  2008-12-31    205563      USD         2008            Q4
# 1    LUV  2009-03-31    205563      USD         2009            Q1
# 2    LUV  2009-06-30    205563      USD         2009            Q2
# 3    LUV  2009-09-30    205563      USD         2009            Q3
# 4    LUV  2009-12-31    205563      USD         2009            Q4
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2009-02-02    2010-01-29     739000000.0       749000000.0  ...
# 1   2009-04-29    2009-04-29     740000000.0       740000000.0  ...
# 2   2009-10-22    2009-10-22     741000000.0       741000000.0  ...
# 3   2009-10-23    2009-10-23     742000000.0       742000000.0  ...
# 4   2010-01-29    2011-02-08     741000000.0       741000000.0  ...
#
#    Treasury Stock  Retained Earnings  Total Equity  \
# 0   -1.005000e+09       4.919000e+09  4.953000e+09
# 1   -9.960000e+08       4.819000e+09  4.928000e+09
# 2   -9.860000e+08       4.900000e+09  5.148000e+09
# 3   -9.780000e+08       4.876000e+09  5.217000e+09
# 4   -9.630000e+08       4.971000e+09  5.454000e+09
#
#    Total Liabilities & Equity     Qtr  Quick Ratio  Current Ratio  \
# 0                 14068000000  2008Q4     0.873129       0.945474
# 1                 14179000000  2009Q1     0.904579       0.959334
# 2                 14027000000  2009Q2     0.943286       1.008475
# 3                 14100000000  2009Q3     0.969246       1.034061
# 4                 14269000000  2009Q4     1.164007       1.246011
#
#    Debt-to-Equity Ratio  Long Term Debt-to-Equity Ratio  \
# 0              1.840299                        0.706239
# 1              1.877232                        0.699472
# 2              1.724747                        0.636752
# 3              1.702703                        0.647499
# 4              1.616245                        0.609644
#
#    Short Term Debt-to-Equity Ratio
# 0                         0.032909
# 1                         0.033076
# 2                         0.020396
# 3                         0.037953
# 4                         0.034837
#
# [5 rows x 36 columns]

# %%
airline_income_df.head()
# Out:
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 0    LUV  2008-12-31    205563      USD         2008            Q4
# 1    LUV  2009-03-31    205563      USD         2009            Q1
# 2    LUV  2009-06-30    205563      USD         2009            Q2
# 3    LUV  2009-09-30    205563      USD         2009            Q3
# 4    LUV  2009-12-31    205563      USD         2009            Q4
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2009-02-02    2011-02-08     739000000.0       749000000.0  ...
# 1   2009-04-29    2010-04-26     740000000.0       740000000.0  ...
# 2   2009-10-22    2010-08-02     741000000.0       741000000.0  ...
# 3   2009-10-23    2010-10-28     742000000.0       742000000.0  ...
# 4   2010-01-29    2012-02-09     741000000.0       741000000.0  ...
#
#    Income (Loss) from Continuing Operations  Net Extraordinary Gains (Losses)  \
# 0                                 -57000000                               NaN
# 1                                 -91000000                               NaN
# 2                                  91000000                               NaN
# 3                                 -16000000                               NaN
# 4                                 115000000                               NaN
#
#    Net Income  Net Income (Common)     Qtr  Gross Profit Margin  \
# 0   -57000000            -57000000  2008Q4             0.208196
# 1   -91000000            -91000000  2009Q1             0.181587
# 2    91000000             91000000  2009Q2             0.233563
# 3   -16000000            -16000000  2009Q3             0.190548
# 4   115000000            115000000  2009Q4             0.246404
#
#    Net Profit Margin  Operating Margin       EPS  Interest Coverage Ratio
# 0          -0.020856          0.025613 -0.077131                -0.077131
# 1          -0.038608         -0.021213 -0.122973                -0.122973
# 2           0.034786          0.047018  0.122807                 0.122807
# 3          -0.006002          0.008252 -0.021563                -0.021563
# 4           0.042420          0.061601  0.155196                 0.155196
#
# [5 rows x 34 columns]

# %%
airline_income_df["Gross Profit Margin"].plot()
# Out:
# <AxesSubplot:>

# %%
#airlines_ratios=pd.concat([airline_income_df[['Ticker',],airline_balsheet_df],axis='columns',join='inner')

# %%
airline_income_df.head()
# Out:
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 0    LUV  2008-12-31    205563      USD         2008            Q4
# 1    LUV  2009-03-31    205563      USD         2009            Q1
# 2    LUV  2009-06-30    205563      USD         2009            Q2
# 3    LUV  2009-09-30    205563      USD         2009            Q3
# 4    LUV  2009-12-31    205563      USD         2009            Q4
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2009-02-02    2011-02-08     739000000.0       749000000.0  ...
# 1   2009-04-29    2010-04-26     740000000.0       740000000.0  ...
# 2   2009-10-22    2010-08-02     741000000.0       741000000.0  ...
# 3   2009-10-23    2010-10-28     742000000.0       742000000.0  ...
# 4   2010-01-29    2012-02-09     741000000.0       741000000.0  ...
#
#    Income Tax (Expense) Benefit, Net  \
# 0                         26000000.0
# 1                         16000000.0
# 2                        -16000000.0
# 3                          4000000.0
# 4                        -69000000.0
#
#    Income (Loss) from Continuing Operations  Net Extraordinary Gains (Losses)  \
# 0                                 -57000000                               NaN
# 1                                 -91000000                               NaN
# 2                                  91000000                               NaN
# 3                                 -16000000                               NaN
# 4                                 115000000                               NaN
#
#    Net Income  Net Income (Common)  Gross Profit Margin  Net Profit Margin  \
# 0   -57000000            -57000000             0.208196          -0.020856
# 1   -91000000            -91000000             0.181587          -0.038608
# 2    91000000             91000000             0.233563           0.034786
# 3   -16000000            -16000000             0.190548          -0.006002
# 4   115000000            115000000             0.246404           0.042420
#
#    Operating Margin       EPS  Interest Coverage Ratio
# 0          0.025613 -0.077131                -0.077131
# 1         -0.021213 -0.122973                -0.122973
# 2          0.047018  0.122807                 0.122807
# 3          0.008252 -0.021563                -0.021563
# 4          0.061601  0.155196                 0.155196
#
# [5 rows x 33 columns]

# %%
df_joined_bal_inc = pd.concat([airline_balsheet_df,airline_income_df],join='inner',axis='columns', keys=['Ticker','Qtr'])
df_joined_bal_inc.head()
# Out:
#   Ticker                                                                       \
#   Ticker Report Date SimFinId Currency Fiscal Year Fiscal Period Publish Date
# 0    LUV  2008-12-31   205563      USD        2008            Q4   2009-02-02
# 1    LUV  2009-03-31   205563      USD        2009            Q1   2009-04-29
# 2    LUV  2009-06-30   205563      USD        2009            Q2   2009-10-22
# 3    LUV  2009-09-30   205563      USD        2009            Q3   2009-10-23
# 4    LUV  2009-12-31   205563      USD        2009            Q4   2010-01-29
#
#                                                  ...  \
#   Restated Date Shares (Basic) Shares (Diluted)  ...
# 0    2010-01-29    739000000.0      749000000.0  ...
# 1    2009-04-29    740000000.0      740000000.0  ...
# 2    2009-10-22    741000000.0      741000000.0  ...
# 3    2009-10-23    742000000.0      742000000.0  ...
# 4    2011-02-08    741000000.0      741000000.0  ...
#
#                                        Qtr                                   \
#   Income (Loss) from Continuing Operations Net Extraordinary Gains (Losses)
# 0                                -57000000                              NaN
# 1                                -91000000                              NaN
# 2                                 91000000                              NaN
# 3                                -16000000                              NaN
# 4                                115000000                              NaN
#
#                                                               \
#   Net Income Net Income (Common)     Qtr Gross Profit Margin
# 0  -57000000           -57000000  2008Q4            0.208196
# 1  -91000000           -91000000  2009Q1            0.181587
# 2   91000000            91000000  2009Q2            0.233563
# 3  -16000000           -16000000  2009Q3            0.190548
# 4  115000000           115000000  2009Q4            0.246404
#
#
#   Net Profit Margin Operating Margin       EPS Interest Coverage Ratio
# 0         -0.020856         0.025613 -0.077131               -0.077131
# 1         -0.038608        -0.021213 -0.122973               -0.122973
# 2          0.034786         0.047018  0.122807                0.122807
# 3         -0.006002         0.008252 -0.021563               -0.021563
# 4          0.042420         0.061601  0.155196                0.155196
#
# [5 rows x 70 columns]

# %%
#airline_stock_qtr.reset_index(level=['AAL',])
#airline_stock_qtr['AAL']['Qtr'] #= Get_Qtr(airline_stock_qtr.index)

#airline_stock_qtr.index[0].date()
#[Get_Qtr(x.date()) for x in airline_stock_qtr.index]
airline_stock_qtr['Qtr'] = Get_Qtr(airline_stock_qtr.index)
airline_stock_qtr.head()
# Out:
#                            AAL                              DAL             \
#                           open high low close volume       open       high
# time
# 2011-01-01 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  11.024532  11.416116
# 2011-04-01 00:00:00-04:00  NaN  NaN NaN   NaN    NaN   9.744524  10.062057
# 2011-07-01 00:00:00-04:00  NaN  NaN NaN   NaN    NaN   7.768752   8.015078
# 2011-10-01 00:00:00-04:00  NaN  NaN NaN   NaN    NaN   8.002381   8.289619
# 2012-01-01 00:00:00-05:00  NaN  NaN NaN   NaN    NaN   9.541855   9.879337
#
#                                                                ...        LUV  \
#                                  low      close        volume  ...        low
# time                                                           ...
# 2011-01-01 00:00:00-05:00  10.624887  11.008461  1.780397e+07  ...  12.258789
# 2011-04-01 00:00:00-04:00   9.398016   9.732794  1.563881e+07  ...  11.555000
# 2011-07-01 00:00:00-04:00   7.424241   7.753981  1.467319e+07  ...   9.015800
# 2011-10-01 00:00:00-04:00   7.663598   7.998611  1.172269e+07  ...   8.161910
# 2012-01-01 00:00:00-05:00   9.181600   9.560661  1.197796e+07  ...   8.817408
#
#                                                           UAL             \
#                                close        volume       open       high
# time
# 2011-01-01 00:00:00-05:00  12.402144  7.578123e+06  24.791613  25.306790
# 2011-04-01 00:00:00-04:00  11.662538  8.935567e+06  23.381508  23.822014
# 2011-07-01 00:00:00-04:00   9.145234  1.048084e+07  19.326484  19.753844
# 2011-10-01 00:00:00-04:00   8.307776  7.918982e+06  19.108548  19.504381
# 2012-01-01 00:00:00-05:00   8.940669  6.046227e+06  20.829758  21.299784
#
#                                                                     timeX  \
#                                  low      close        volume
# time
# 2011-01-01 00:00:00-05:00  24.315805  24.778368  6.762292e+06  2011-01-01
# 2011-04-01 00:00:00-04:00  22.946525  23.350222  7.071027e+06  2011-04-01
# 2011-07-01 00:00:00-04:00  18.814000  19.258125  6.858209e+06  2011-07-01
# 2011-10-01 00:00:00-04:00  18.632379  19.073811  5.282887e+06  2011-10-01
# 2012-01-01 00:00:00-05:00  20.457177  20.881166  6.356818e+06  2012-01-01
#
#                               Qtr
#
# time
# 2011-01-01 00:00:00-05:00  2011Q1
# 2011-04-01 00:00:00-04:00  2011Q2
# 2011-07-01 00:00:00-04:00  2011Q3
# 2011-10-01 00:00:00-04:00  2011Q4
